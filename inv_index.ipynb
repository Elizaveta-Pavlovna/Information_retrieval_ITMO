# %%
# Подключаем библиотеки

# Для парсинга файла html
from bs4 import BeautifulSoup 
import re
import os
import fnmatch
import numpy as np

# Создаем список, элементы которого будут представлять текст статьи на опредленную тему. 
collection = []

# Всего областей 5: a) биология, b) информационные технологии, c) история, d) менеджмент, 
# e) архитектура и строительство
# Создадим список, в котором каждому номеру документа соответствует область
field = []


# Читаем все файлы из папки dataset
for filename in os.listdir("dataset"):
    with open(os.path.join("dataset", filename), "rb") as f:
        contents = f.read().decode(errors='replace')
        soup = BeautifulSoup(contents, 'html.parser')
        
        a = soup.find_all('p', style = re.compile("[\D+]?text-align: justify;"))
        s = ''
        
        for i in range(len(a)):
        
# Некоторые атрибуты в файле имели пустые значения и при записи почему-то записывались как \xa0, поэтому
# пришлось проводить проверку на то, чтобы a[i].text != '\xa0' и только потом записывать в общую строку
            if a[i].text != '\xa0':
                s += ' ' + re.sub('[a-zA-Z0-9%-.,:—;"!№/\[\]\\\'?»«–’”“℃]','',a[i].text.lower())
         
    
# При парсинге не получалось удалить некоторые объекты, пришлось ручками.
    s = s.replace('\u200b','')
    s = s.replace('\xad', '')
    s = s.replace('\xa0', '')
    collection.append(s)
    
    if fnmatch.fnmatch(filename, 'a*.html'):
        field.append('Биология')
    elif fnmatch.fnmatch(filename, 'b*.html'):
        field.append('Информационные технологии')
    elif fnmatch.fnmatch(filename, 'c*.html'):
        field.append('История')
    elif fnmatch.fnmatch(filename, 'd*.html'):
        field.append('Менеджмент')
    elif fnmatch.fnmatch(filename, 'e*.html'):
        field.append('Архитектура')
    else: field.append('1')
    
collection.remove(collection[14])
field.remove(field[14])

# field

# Мощность датасета и пример одного элемента 
# print(len(collection))
# print(collection[108])

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Данные уже :
# 1. приведены к нижнему регистру
# 2. отчищены от пунктуационных знаков
# 3. отчищены от спец.знаков
#
# В этом разделе:
# 1. избавимся от стоп-слов
# 2. проведем лемматизацию

# %%
import math

def idf(word, corpus):
        return math.log10(len(corpus)/sum([1.0 for i in corpus if word in i]))

# %%
collection_split = [collection[i].split() for i in range(len(collection))]

data = []
for i in range(len(collection_split)):
    data.append(list(filter(lambda x: idf(x,collection_split) > 0.5, collection_split[i])))
# data[0]

# %%
# Напишем функцию для лемматизации текста и выведем коллекцию статей снова

import pymorphy2

morph = pymorphy2.MorphAnalyzer()

def lemmat(data):
    res_data = []
    for words in data:
        res_line = []
        for word in words:
            res_line.append(morph.parse(word)[0].normal_form)
        res_data.append(' '.join(res_line)) 
    return res_data

collection = lemmat(data)

# %%
data = [collection[i].split() for i in range(len(collection))]
# data

set_data = set(data[0])
for i in range(len(data)):
    set_data |= set(data[i])
               
len(set_data)
# set_data
# Out:
# 8898

# %% [markdown]
# # TF-IDF

# %%
import collections

def tf(word, text):
    w_count = 0
    for i in text:
        if i == word:
            w_count += 1
    return w_count / float(len(text))

# %%
# На вход подается слово, документ и вся коллекция (оба в виде списков слов)
# На выходе - tf-idf значение для слова в документе

def tf_idf(word, text, collection):
    return tf(word, text) * idf(word, collection)

# %% [markdown]
# # Построение обратного индекса

# %%
inverted = {}

for i in range(len(data)):
    for j in range(len(data[i])):
        if data[i][j] not in inverted:
            inverted[data[i][j]] = [i]
        elif i not in inverted[data[i][j]]:
            inverted[data[i][j]].append(i)
            
# inverted

# %%
def fast_search(text, set_data):
    set_w = set()
    for word in text:
        if word in inverted:
            set_w |= set(inverted[word])  # Ищем объединение всех документов
    return set_w

# %% [markdown]
# # Поиск по запросу

# %%
# Введем запрос и преобразуем его
search = 'Виды растений и животных'
search = lemmat([search.lower().split()])[0].split()
search
# Out:
# ['вид', 'растение', 'и', 'животное']

# %%
# Список всех документов, в которых используется хотя бы одно слово из запроса

search_docs = list(fast_search(search, set_data))
# search_docs

# %% [markdown]
# # Ранжирование (tf-idf)

# %%
# Ранжируем, используя значения tf-idf

rang = {}
for i in search_docs:
    rang[i] = 0.0
    for word in search:
        if word in inverted:
            rang[i] += tf_idf(word, data[i], data)

# rang

# %%
res_rang = list(rang.items())
res_rang.sort(key = lambda i: i[1])

for index in reversed(res_rang):
    print(index[0], ':', index[1])
# Out:
# 25 : 0.046812343130920725
# 82 : 0.036920854441251094
# 14 : 0.03544160508397547
# 73 : 0.027816851589629727
# 89 : 0.020028838599338638
# 105 : 0.019753478940449837
# 103 : 0.017446778904692387
# 50 : 0.016914366441242987
# 41 : 0.01623392483167811
# 49 : 0.013214390181444375
# 72 : 0.01280450626873142
# 96 : 0.00996067491212343
# 56 : 0.0038149626817522778
# 7 : 0.0032974898574089535
# 40 : 0.0031541007294546754
# 28 : 0.0023439138533112385
# 84 : 0.002293479233967332
# 43 : 0.002198326571605969
# 31 : 0.0015887121776961203
# 75 : 0.001415465142077286
# 104 : 0.0013960308380670716
# 77 : 0.0013320206904701096
# 52 : 0.0013320206904701096
# 32 : 0.0013054182801040875
# 57 : 0.0012250310767777314
# 39 : 0.0011709510100485802
# 80 : 0.001048222467758265
# 55 : 0.001048222467758265
# 94 : 0.0009935919808392675
# 68 : 0.0009935919808392675
# 70 : 0.0009903660328495296
# 0 : 0.0009850357528019005
# 23 : 0.0009652934750558706
# 10 : 0.0009652934750558706
# 4 : 0.0009652934750558706
# 62 : 0.0008841528641091454
# 13 : 0.000881597509010564
# 46 : 0.0008715221089075861
# 58 : 0.0008641154054324509
# 93 : 0.000847313161437931
# 2 : 0.0008221906687807416
# 35 : 0.0008048357206270584
# 26 : 0.0007922928262796237
# 98 : 0.0006854668272306858
# 60 : 0.0006531750280891973
# 48 : 0.0005843539044399523
# 83 : 0.0005437303709762123
# 88 : 0.0004992352506017269
# 61 : 0.000481124192614598
# 20 : 0.0004796112234554326
# 38 : 0.0003697366522638244
# 79 : 0.00035844035031451835
# 24 : 0.0003090503932296405
# 100 : 0.00025894120383502134
# 99 : 0.000256330032031643
# 45 : 0.00023710278905375449

# %%
for index in reversed(res_rang[-20:]):
    if index[1] != 0.0:
        print(field[index[0]])
        print(index[0])
#         print(collection[index[0]])
        print('\n')
# Out:
# Биология
# 25
#
#
# Биология
# 82
#
#
# Биология
# 14
#
#
# Биология
# 73
#
#
# Биология
# 89
#
#
# Биология
# 105
#
#
# Биология
# 103
#
#
# Биология
# 50
#
#
# Биология
# 41
#
#
# Биология
# 49
#
#
# Биология
# 72
#
#
# Биология
# 96
#
#
# Архитектура
# 56
#
#
# Биология
# 7
#
#
# Архитектура
# 40
#
#
# Архитектура
# 28
#
#
# Информационные технологии
# 84
#
#
# История
# 43
#
#
# Менеджмент
# 31
#
#
# Архитектура
# 75

# %% [markdown]
# # Ранжирование (Word2Vec)

# %%
# Напишем функцию для векторизации документ. Усредним оценки для всех слов в предложении

def vec_w2v(model, text):
    sum_ = 0
    for j in range(len(text)):
        sum_ += model.wv[text[j]]
    return sum_ / len(text)

# %%
# Введем запрос и преобразуем его
search_w2v = 'Виды растений и животных'
search_w2v = lemmat([search_w2v.lower().split()])[0].split()
search_w2v
# Out:
# ['вид', 'растение', 'и', 'животное']

# %%
from gensim.models import Word2Vec

data.append(search_w2v)

word2vec = Word2Vec(data, min_count = 1)
vec_search_w2v = vec_w2v(word2vec, search_w2v)

# %%
# vec_w2v(word2vec, data[1])

# %%
# Напишем функцию, высчитывающую косинусное расстояние

def cos(vec1, vec2):
    vec1 = np.array(vec1)
    vec2 = np.array(vec2)
    return np.dot(vec1, vec2) / np.linalg.norm(vec1) / np.linalg.norm(vec2)

# %%
# Построим список косинусного расстояния между вектором запроса и векторами статей

scalar = {}
for i in search_docs:
    scalar[i] = cos(vec_w2v(word2vec, data[i]), vec_search_w2v)

# scalar

# %%
# Создание словаря с номерами статей и соответствующими косинусными расстояниями. 
# Словарь сортируется по возрастанию косинусного расстояния. А выводит в обратном порядке, для наглядности.

list_rang_index = list(scalar.items())
list_rang_index.sort(key = lambda i: i[1])

for index in reversed(list_rang_index):
    print(index[0], ':', index[1])
# Out:
# 82 : 0.999836
# 73 : 0.9998247
# 25 : 0.9998246
# 49 : 0.9998184
# 50 : 0.99981517
# 62 : 0.99981356
# 72 : 0.9998104
# 103 : 0.9998098
# 89 : 0.9998084
# 105 : 0.9998065
# 7 : 0.99980474
# 14 : 0.99980325
# 41 : 0.9998019
# 60 : 0.9997992
# 100 : 0.99979836
# 98 : 0.9997962
# 61 : 0.99979466
# 83 : 0.9997942
# 48 : 0.99979323
# 43 : 0.99979234
# 13 : 0.99979216
# 75 : 0.9997915
# 104 : 0.9997912
# 70 : 0.999791
# 40 : 0.9997905
# 58 : 0.9997894
# 88 : 0.99978834
# 45 : 0.99978834
# 80 : 0.9997858
# 55 : 0.9997858
# 28 : 0.9997853
# 57 : 0.9997846
# 99 : 0.99978393
# 46 : 0.99978304
# 24 : 0.9997829
# 31 : 0.99978244
# 0 : 0.9997797
# 96 : 0.99977905
# 10 : 0.99977905
# 77 : 0.9997784
# 52 : 0.9997784
# 32 : 0.99977726
# 79 : 0.99977565
# 38 : 0.999774
# 20 : 0.99977314
# 94 : 0.9997726
# 68 : 0.9997726
# 2 : 0.9997704
# 35 : 0.9997697
# 84 : 0.9997675
# 56 : 0.99976176
# 93 : 0.99975616
# 26 : 0.9997519
# 23 : 0.9997478
# 4 : 0.9997478
# 39 : 0.9997291

# %%
# Выведем первые 10 подходящих статей. Я вывожу области, из которых взяты статьи, чтобы предварительно показать
# качество работы модели. Вывод самих статей закомментирован. Чтобы посмотреть - раскомментируйте 7ю строку.
for index in reversed(list_rang_index[-10:-5]):
        print(field[index[0]])
        print(index[0])
        print(collection[index[0]])
        print('\n')
# Out:
# Архитектура
# 62
# представлять себя крепость который земля почти остаться след крепость который сохраниться земля статья посвятить исследование крепость ям работа рассматриваться история градостроительный период археология крепость археология история фортификация один уникальный объект культурный наследие г кингисепп крепость ям исторический центр исторический код пространственный история крепость начинаться древний время главный источник изучение первый страница история ямгород летопись новгородский летописец сообщить закладка город камена р луга г яма дорожный станция возле речной переправа крепость ям являться оборонительный щит северозападный граница русь наряду другой крепость новгородский земля долгий крепость принимать себя удар ливонский орден поскольку она стать главный цитадель западный граница новгородский республика г крепость ям быть окончательно закрепить российский государство указ пётр подтверждать название город ямгород касаться строительство крепость здесь отметить тот факт оборонный зодчество период древнерусский государство занимать особый место архитектура первоначальный облик крепость ям сохраниться исторический гравюра описание позволять воссоздать исторический облик главный гравюра адам олеария ‑х год изучение особенность оборонительный архитектура данный период позволить приблизиться воссоздание облик каменный крепость ям исследование крепость бастионный тип российский историография заниматься н кирпичник п раппопорт детально изучение бастионный укрепление крепость ямбург заниматься н ю скрипинский период пребывание новгородский крести ям швед меняться укрепление тип европейский бастея новый трансформация оборонительный сооружение связать первый очередь изменение тактика осада крепость усовершенствование артиллерия бастионный ограда европа россия получить широкий распространение представлять себя укрепление являться свой род дополнительный защита башня крепость начинать эпоха пётр бастион стать неотъемлемый часть русский цитадель крепость ям памятник история археология протяжение долгий объект исследование историк археолог краевед археологический исследование археологический раскопка позволять мы открывать новый страница многовековый история крепость благодаря изучение земляной напластование насыпь составлять археологический стратиграфия ответить ряд вопрос взаимосвязанный слой сооружение определить датировка применение междисциплинарный метод давать возможность исследователь изучить детально аспект фортификационный сооружение воссоздать картина исторический прошлое начало археологический раскопка крепость положить н кирпичников х год этот больший объём раскопка быть чётко зафиксировать сохранность нижний часть стена башня археологический исследование н кирпичников впервые получить фотокопия чертёж крепость шведский королевский военный архив положить конец спор историк повод четырехбашенный укрепление предоставить план дать возможность разрешить спорный вопрос поновое взглянуть история один главный щит новгородский русь результат археологический раскопка заложить девять раскоп составлять общий площадь кв метр впервые провести археологический исследование крепость архитектурный дальнейший археологический изыскание касаться сооружение детинец благодаря расчистка часть городище который примыкать берег р луга выявить воротный устройство ямгородской вышгород сам башня детинец основа исследование н кирпичник прийти вывод детинец представлять себя самостоятельный укрепление ещё один уникальный находка период археологический исследование стать остаток нижний часть храм заложить честь святой михаил архистратиг летописец строительство каменный крепость ям связывать имя святой результат археологический исследование архитектурный сопоставление учёный предложить датировать храм хх год результат широкомасштабный археологический раскопка проводиться хх год н кирпичников быть г арашовой быть выполнить условный реконструкция крепость ям представить модель реконструкция крепость конечно условный поскольку свой первоначальный вид крепость ...
#
#
# Биология
# 72
# один интересный свойство живой организм регенерация способность который обладать животное планарий относиться классический объект исследование регенерация эмбриогенез морфология физиология нервный знание современный классификация группа точный диагностический характеристика вид необходимый условие успешный экспериментальный усиленный последний год интерес планарий удобный объект теоретический экспериментальный морфология приводить резкий увеличение поток научный информация выявить ход эксперимент спектр поведенческий физиологический реакция доступность планарий окружающий водоём сравнительный простота лабораторный содержание позволять рекомендовать качество индикаторный представительный тестобъект исследование антропогенный воздействие последний десятилетие после расшифровка геном человек начать работа расшифровка ген другой биологический объект сравнение ген человеческий результат сиквенирование геном планарий показать многие ген ответственный основной процесс клеточный пролиферация дифференцировка гомологичный человеческий это планарий выгодно отличаться такой известный модельный животное круглый черви плодовый мушка многий человеческий ген просто нет впервые метод прижизненный морфометрия регенерация планарий быть применить работа хптираса нюсахаров который морфологический параметр сфотографировать планарий измерять помощь линейка дальнейший метод быть усовершенствовать анализ изображение планарий быть использовать дигитайзер координата контур планарий вводиться оператор память компьютер далее программа определять морфологический параметр тело планарий тираса хачко материал исследование работа тираса хп сотрудник применяться бесполый раса пресноводный червейпланарий планариинебольший животное покрыть коричневый чёрный пигментный клетка размер мм поверхность тело планарий покрыть ресничный эпителий помощь ресничка планарий перемещаться субстрат плёнка поверхность вода способность плавание планарий обладать эволюция плоский червипервый таксономический группа появляться централизованный нервный система нервный система планарий контролировать физиологический процесс планарий питание размножение контроль нервный находиться процесс регенерация планарий планарииединственный таксономический группа животное способный регенерация восстановление после ампутация свой центральный нервный системыголовный ганглий размножение планарий происходить половой бесполый путём метод поперечный разделение тело фрагмент бесполый размножение планарий приклеивать помощь слизь свой хвост поверхность затем двумятремить энергичный рывок отрывать тело приклеить участок неделя содержание кормление молодой планарий достигать размер мм использовать эксперимент лаборатория планарий содержать температура вода ° стеклянный пластиковый контейнер объём литр контейнер помещаться стеллаж шкаф затенить условие следовать избегать попадание прямой солнечный свет планарий вода содержание планарий культурный вода смесь дистиллировать вода водопроводный вода пропорция мы провести исследование влияние энергетический напиток процесс регенерация планарий вид энергетический напиток напиток делаться акцент способность стимулировать центральный нервный система человек антиседативный эффект напиток содержать вещество тонизировать вещество частый кофеин другой стимулятор теобромин теофиллин основный компонент являетсятаурин поместить декапитировать планарий три ёмкость напиток один другой третий разбавленный соотношение ½ дистилировать вода наблюдать каждый деньи следующий день декапитировать планарий энергетик гиблидадкий раствориться получить результат исследование свидетельствовать планарий энергетический напиток полностью раствориться воздействие основный компонент входящий состав энергетический напиток таурина кофеин нарушаться процесс митоз клетка тело планарий погибать течение сутки
#
#
# Биология
# 103
# планета насчитываться около сорок тысяча вид клоп настолько сильно отличаться друг друг свой жизнь стиль питание внешний вид часто специалист способный распознать жук насекомое немногий объединять черта мы мочь назвать строение ротовой аппарат общий тип клоп паразит насекомое немногий объединять черта мы мочь назвать строение ротовой аппарат общий тип независимо вид колючий присоска клоп некоторый вид питаться кровь другой сок растение питательный жидкость бывать разный принцип всасывание один тот ещё один яркий признак клоп специфический довольно сильный запах выделять специальный железа расположить брюшко насекомое первый второй пара лапа один сторона выполнять коммуникативный роль особь один вид химический уровень состав выделять жидкость близкий феромон другой сторона отпугивать враг вот наверное объединять представитель разный вид далёкий начинаться особенность среди жуков обитать сад огород есть вредитель защитник спасти урожай другой насекомое защитник относиться жуксолдат верно служить садовод поедать яйцо насекомыхвредитель ещё один распространить вредитель сад огород черепахаклоп страдать молодой дерево саженец прилипать зелёный побег высасывать они сок водоплавающий насекомое относиться водяной шумовщик гладкий рыба который называть водяной оса оба вид хищник охотиться комар личинка мошка другой мелкий насекомое обитать над поверхность водоём оба вид бороздить водный простор пруд озеро изредка выбираться суша оба вид иметь хорошо развитой крыло позволять они преодолевать больший расстояние поиск хороший место жизнь похожий почти весь кроме внешний вид элегантный водный фигуристка легко скользящий водный гладь лёд выглядеть грациозный балерина сравнение широкоплечий богатырский телосложение гладкий нельзя назвать гармоничный пара видимо предпочитать селиться разный водоём больший группа состоять паразитический клоп питаться кровь крупный организм около вид паразитировать животное птица летучий мышь некоторый вид предпочитать человеческий кровь яркий представитель домашний постельный клоп средний продолжительность жизнь жук составлять около месяц хотя этот цифра очень условный любой изменение температурный режим помещение влиять продолжительность существование повышение температура ускорять развитие сокращать жизненный цикл понижение температура напротив замедлять созревание развитие новый поколение увеличивать общий продолжительность жизнь жук превращаться лёд состояние сохранять он жизнь когда температура повышаться жизнерадостный паразит оттаивать набрасываться еда удвоенный аппетит температура ниже минус градус выше плюс убить помимо экстремально низкий экстремально высокий температура клоп бояться резкий сильный запах физически запах клоп конечно уничтожить способный отпугнуть заставить мигрировать запах относиться столовый уксус ацетон дух сильный аромат нашатырный спирт денатурированный спирт керосин скипидар запах некоторый растение некоторый отпугнуть клоп эффективный они полынь пижма подробный какой запах бояться клоп вы мочь узнать отдельный статья серьёзный борьба большой популяция клоп хороший использовать профессиональный инсектицид соответствовать оборудование
#
#
# Биология
# 89
# один интересный свойство живой организм регенерация способность который обладать животное планарий относиться классический объект исследование регенерация эмбриогенез морфология физиология нервный знание современный классификация группа точный диагностический характеристика вид необходимый условие успешный экспериментальный усиленный последний год интерес планарий удобный объект теоритический экспериментальный морфология приводить резкий увеличение поток научный информация последний десятилетие после расшифровка геном человек начать работа расшифровка ген другой биологический объект сравнение ген человеческий впервые метод прижизненный морфометрия регенерация планарий быть привести работа хп тираса ню сахаров который морфологический параметр сфотографировать планарий измерять помощь линейка материал исследование работа тираса хп сотрудник применяться бесполый раса пресноводный червейпланарий планариинебольший животное покрыть коричневый чёрный пигментный клетка размер мм поверхность тело планарий покрыть ресничный эпителий помощь ресничка планарий перемещаться субстрат плёнка поверхность вода способность плавание планарий обладаютвод содержание планарий культурный вода смесь дистиллировать водопроводный вода пропорция эксперимент использовать животное после дневный голоданиять процесс эксперимент животное кормилидлить эксперимент отбирать животныхдлин составить мм мы провести исследование влияние антибиотик регенарация планарий вид антибактериальный средство антибиотик вещество способный подавлять рост живой микроорганизм приводить гибель применять медицинский цель вещество должный эффективный малый концентрация способный подавлять патогенный микрофлора практически наносить ущерб макроорганизм цефалексин цефалоспориновый антибиотик поколение действовать бактерицидный нарушать синтез клеточный стенка микроорганизм достаточно устойчивый пенициллиназа грамположительный микроорганизм разрушаться беталактамаз грамотрицательный микроорганизм амоксициллин антибиотик широкий спектр действие группа полусинтетический пенициллин действовать бактерицидный ингибировать транспептидаза нарушать синтез пептидогликан период деление рост вызывать лизис микроорганизм активный отношение грамположительный кокковый качество исследовать вещество взять антибиотик препарат действие одинаково этот вещество предварительно растворить вода два час часть планарий погибнуть получить результат исследование свидетельствовать амоксициллин цефалексин вода концентрация мл подавить живой организм
#
#
# Биология
# 105
# маковый относиться один знаменитый хотя скорее печально известный растение мак опийный реальный известный лишь культура алкалоид морфин андроца млечный сок добывать основное незрелый коробочка мак иметь ряд алкалоид довольно ценить медицина морфин наркотин кодеин др курение опиум тот нарочно переработать млечный сок исстари распространить азиатский государство борение правительство напротив ввоз курение опиум временами приводить истинный война пример например именовать опиумный война меж англия китай произойти далее впоследствии ликвидирование китаец большой чем ящик опийный сырьё любопытно собственно взрослый семечко мак употреблять кондитерский индустрия абсолютно содержать морфин выделять ещё третий подсемейство гипекоумовый куда относиться упоминаться выше небольшой родиться гипекоум нуресоить поскольку андроцей последний выводить своеобразный тычинка дымянков андроца крестоцветный рассматривать часто качество исходный группа семейство маковый тогда большой тычинка мак другой роды очевидный вторичный признак систематический положение маковый очевидный особенно спорный родство ниже описывать семейство часто объединять маковый один порядок макоцветной родиться мак насчитывать около вид однолетний многолетний травянистый растение содержать млечный сок цветок одиночный длинный цветонос лепестковый ярко окрасить тычинка многочисленный рыльце звездчатый сидячий плод верхний паракарпный коробочка шаровидный ложный перегородка дикий вид открываться отверстие рыльце мак масличный опийный однолетник ствол незатейливый ветвистый цветоножка оттопырить строгий волосок бутон пониклый мя чашелистик опадать раскрывание цветок семечко маленький богатый шелом бессчётный зеленоватый коробочка метод надрез добывать млечный сок сгущаться воздух темнеть преобразоваться довольно важный врачебный сырьё давать алкалоид идти приготовление медицинский препарат семя получать важный пищевой технический высыхать жирный масло максамосейка однолетник покрыть оттопырить волосок цветок красный коробочка рыльце вскрываться дырочка лекарственный свойство обладать представитель род чистотел многолетний трава млечный сок жёлтый цвет плод стручковидный коробочка раскрываться весь длина россия повсеместно распространить ч крупный цветок жёлтый сорный растение сад весь россия ядовитый лекарственный растение мачок глауциум рогатый однолетник двулетник юг сорный растение южный средний полоса россия

# %%
data.pop(len(data)-1)
# Out:
# 'Сам запрос'

# %% [markdown]
# # Вывод

# %% [markdown]
# Видно, что разные методы выдают разные результаты. Word2Vec уже 6-ым выдает статью из области "Информационные технологии", в которой нет ни слова "растение", ни "животное". Есть только слово "вид", а оно не самое значимое в запросе.
#
# Ранжирование по TF-IDF работает лучше: первые 12 статей из области "Биология", а следующие содержат главные слова - "растение" или "животное"

# %%
# Введем запрос и преобразуем его
search = 'Вид тип разновидность семейство растений трава цветы и животных скот зверь'
search = lemmat([search.lower().split()])[0].split()
search
# Out:
# ['вид',
#  'тип',
#  'разновидность',
#  'семейство',
#  'растение',
#  'трава',
#  'цветок',
#  'и',
#  'животное',
#  'скот',
#  'зверь']

# %%
# Ранжируем, используя значения tf-idf

rang = {}
for i in search_docs:
    rang[i] = 0.0
    for word in search:
        if word in inverted:
            rang[i] += tf_idf(word, data[i], data)

# rang

# %%
res_rang = list(rang.items())
res_rang.sort(key = lambda i: i[1])

# for index in reversed(res_rang):
#     print(index[0], ':', index[1])

# %%
for index in reversed(res_rang[-20:]):
    if index[1] != 0.0:
        print(field[index[0]])
        print(index[0])
#         print(collection[index[0]])
        print('\n')
# Out:
# Биология
# 50
#
#
# Биология
# 49
#
#
# Биология
# 25
#
#
# Биология
# 105
#
#
# Биология
# 82
#
#
# Биология
# 14
#
#
# Биология
# 73
#
#
# Биология
# 103
#
#
# Биология
# 89
#
#
# Биология
# 41
#
#
# Архитектура
# 26
#
#
# Биология
# 72
#
#
# Менеджмент
# 99
#
#
# Биология
# 96
#
#
# История
# 43
#
#
# Информационные технологии
# 0
#
#
# Информационные технологии
# 23
#
#
# Информационные технологии
# 4
#
#
# Архитектура
# 13
#
#
# Архитектура
# 56
